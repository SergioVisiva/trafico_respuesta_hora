# %%
import utils as u
# Out:
# 2025-11-08 11:58:54.352 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-08 11:58:54.356 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
u.generar_df_dia_mes(2025,11)
# Out:
#         fecha  num_dia nom_dia num_nom
# 0  2025-11-01        1     sáb   1 sáb
# 1  2025-11-02        2     dom   2 dom
# 2  2025-11-03        3     lun   3 lun
# 3  2025-11-04        4     mar   4 mar
# 4  2025-11-05        5     mié   5 mié
# 5  2025-11-06        6     jue   6 jue
# 6  2025-11-07        7     vie   7 vie
# 7  2025-11-08        8     sáb   8 sáb
# 8  2025-11-09        9     dom   9 dom
# 9  2025-11-10       10     lun  10 lun
# 10 2025-11-11       11     mar  11 mar
# 11 2025-11-12       12     mié  12 mié
# 12 2025-11-13       13     jue  13 jue
# 13 2025-11-14       14     vie  14 vie
# 14 2025-11-15       15     sáb  15 sáb
# 15 2025-11-16       16     dom  16 dom
# 16 2025-11-17       17     lun  17 lun
# 17 2025-11-18       18     mar  18 mar
# 18 2025-11-19       19     mié  19 mié
# 19 2025-11-20       20     jue  20 jue
# 20 2025-11-21       21     vie  21 vie
# 21 2025-11-22       22     sáb  22 sáb
# 22 2025-11-23       23     dom  23 dom
# ...
